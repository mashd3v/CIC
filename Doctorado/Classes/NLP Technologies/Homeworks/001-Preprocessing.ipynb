# %%
import sys
sys.path.append('/Users/mash/Documents/Git/ciencias_de_la_computacion/Doctorado/Scripts')

# %%
import text_preprocessing as tp
import pandas as pd, numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 9.9 MB/s eta 0:00:00:00:0100:01
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 7.6 MB/s eta 0:00:0000:0100:01m
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [nltk_data] Downloading package stopwords to /Users/mash/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
filename = '../data/e990519_mod.htm'
text_file = open(filename, encoding='utf-8')
text = text_file.read()
text_file.close()

# %%
print(text)
# Out:
# <!DOCTYPE html>
# <html lang='es'>
# <head>
# <meta charset='UTF-8'>
# <title>e990519_mod.htm</title>
# </head>
# <body>
#
# http://www.excelsior.com.mx/9905/990519/art01.html
#
#
# <title>Excelsior: Editorial</title>
#
#
# <basefont size="3">
# <img src="/gifs/ban_editorial.gif">
# <hr><h5 align="right">Miércoles 19 de Mayo de 1999
# </h5>
# <h3>Epigrama
# </h3><p></p><p>
# <b>JORGE MANSILLA TORRES</b></p><p>
# </p><p>
# Con honores militares enterraron en Chihuahua al soldado villista Manuel S. Tarando, de 101 años.</p><p>
# </p><p>
# Quiero en vida los honores,</p><p>
# dijo el villista Tarando,</p><p>
# porque muerto ni con flores</p><p>
# sabré quién, cómo ni cuándo.</p><p>
# </p><hr><center><font size="-1">
# <a href="editorial.html">Editorial</a> -
# <a href="art02.html">Nota siguiente</a>
# </font></center>
# http://www.excelsior.com.mx/9905/990519/art02.html
#
#
# <title>Excelsior: Editorial</title>
#
#
# <basefont size="3">
# <img src="/gifs/ban_editorial.gif">
# ...

# %%
prep_es = tp.Preprocessing(language='spanish')
data_training_es = prep_es.main_preprocess(text, lemmatize=True, remove_stop_words=True)

# %%
print(data_training_es)
# Out:
# mod htm http ww excelsior com mx html excelsior editorial miercoles mayo epigrama jorge mansilla torre honor militar enterrar chihuahua soldado villista manuel s tarandir a o querer vida honor decir villista tarar muerto flor sabre editorial nota siguiente http ww excelsior com mx html excelsior editorial miercoles mayo pri cesarismo batracomaquia leon garcia soler votar favor seguir dar cesar ir funcionar decir alfonso martinez dominguez abandonar salon compa ero partido ejercitar retorica parlamentario superar propio miedo ejercitar fuerza soberano decir inauguraban cuarto etapa partido pnr prm pri hablar votar favor consulta directo bas ampliar conjuro democracia abarcar simpatizante cuanto ciudadano disponer credencial elector fotografia guerra galaxias vencer contienda ganar mayor numero distrito electoral universal eleccion indirecto hablar satisfecho orondo jose antonio gonzalez fernandez intentar acu ar epitafio presidencialismo mexicano nombre candidato pasar pino esperar pr
# ...

# %%
# Guarda en una variable todas las palabras del texto que esta en la variable data_training_es
words = data_training_es.split()

# %%
print(words)
# Out:
# ['mod', 'htm', 'http', 'ww', 'excelsior', 'com', 'mx', 'html', 'excelsior', 'editorial', 'miercoles', 'mayo', 'epigrama', 'jorge', 'mansilla', 'torre', 'honor', 'militar', 'enterrar', 'chihuahua', 'soldado', 'villista', 'manuel', 's', 'tarandir', 'a', 'o', 'querer', 'vida', 'honor', 'decir', 'villista', 'tarar', 'muerto', 'flor', 'sabre', 'editorial', 'nota', 'siguiente', 'http', 'ww', 'excelsior', 'com', 'mx', 'html', 'excelsior', 'editorial', 'miercoles', 'mayo', 'pri', 'cesarismo', 'batracomaquia', 'leon', 'garcia', 'soler', 'votar', 'favor', 'seguir', 'dar', 'cesar', 'ir', 'funcionar', 'decir', 'alfonso', 'martinez', 'dominguez', 'abandonar', 'salon', 'compa', 'ero', 'partido', 'ejercitar', 'retorica', 'parlamentario', 'superar', 'propio', 'miedo', 'ejercitar', 'fuerza', 'soberano', 'decir', 'inauguraban', 'cuarto', 'etapa', 'partido', 'pnr', 'prm', 'pri', 'hablar', 'votar', 'favor', 'consulta', 'directo', 'bas', 'ampliar', 'conjuro', 'democracia', 'abarcar', 'simpatizante', 'cua
# ...

# %%
len(words)
# Out:
# 57578
