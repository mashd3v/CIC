# %%
# !git clone https://github.com/CCogS-Mx/text-preprocessing.git
# Out:
# Cloning into 'text-preprocessing'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 54 (delta 16), reused 44 (delta 11), pack-reused 0
# Unpacking objects: 100% (54/54), 21.99 KiB | 1.37 MiB/s, done.

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('text-preprocessing/script/')
sys.path.append('Scripts/')

# %%
import os
import pandas as pd
import numpy as np

# Import classes
import text_preprocessing as tp
import feature_extraction as fe
import robust_classic_model as rcm
import cleaning_twitter_data as ctd

# Algoritmos de ML
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV

# Vectorizadores
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\qk_le\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\qk_le\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\qk_le\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Data

# %%
main_path = 'Data/'
training = pd.read_csv(f'{main_path}homomex_training.csv').drop('index', axis=1)

# %%
training.head()
# Out:
#                                               tweets label
# 0  Me quise ligar a una chava ayer y no me pelo, ...     P
# 1           @papaya_rockera eres un puñal, Papayita.     P
# 2  Magnate ofrece 130 mdd al hombre que conquiste...     P
# 3  Los trolebuses del desgobierno de @EPN son idi...     P
# 4  En época de Hitler no se decía "eres gay" y, s...     P

# %%
prep = tp.Preprocessing('spanish')

# %%
training_p = prep.main_preprocess(data=training, 
                                  column='tweets', 
                                  tweet=True, 
                                  tweet_tags=True, 
                                  remove_stop_words=False, 
                                  lemmatize=False, 
                                  translate_emojis=True)

# %%
training_p.head()
# Out:
#                                               tweets label
# 0  me quise ligar a una chava ayer y no me pelo l...     P
# 1                             eres un punal papayita     P
# 2  magnate ofrece mdd al hombre que conquiste a s...     P
# 3  los trolebuses del desgobierno de son idiotas ...     P
# 4  en epoca de hitler no se decia eres gay y si e...     P

# %%
training_p.label = training_p.label.fillna('NR')

# %%
dictionary_list = [{'P': 0, 'NP': 1, 'NR': 2}]

# %%
training_p.label.replace(list(dictionary_list[0].keys()), 
            list(dictionary_list[0].values()), 
            inplace=True)

# %%
training_p.label.value_counts()
# Out:
# label
# 1    4360
# 2    1778
# 0     862
# Name: count, dtype: int64

# %% [markdown]
# ## Finding best hyperparams (TP)

# %%
from sklearn.model_selection import KFold, GridSearchCV

# %%
models = [LogisticRegression(), RandomForestClassifier(), LinearSVC(), KNeighborsClassifier()]
model_names = ['Regresión logística', 'Random Forest', 'SVM Lineal', 'KNN']
x_label_column = 'tweets'
y_label_column = 'label'
folds = 5
grid_params  = [{"C":np.logspace(-3,3,7), "penalty":["l2"], "max_iter": [1000, 10000], "random_state":[42]},
                {"n_estimators": [10, 50, 100], "max_depth":[10, 50, 100], "random_state": [42]},
                {"C":np.logspace(-3,3,7), "penalty":["l2"], "max_iter": [1000, 10000], "random_state":[42]},
                {"n_neighbors":[3], "weights":['uniform', 'distance']}]
path_to_save_models = ''
path_to_save_vectorizers = ''
vectorizers = [CountVectorizer(ngram_range = (1,1), lowercase = False), TfidfVectorizer(ngram_range = (1,1), lowercase = False)]
vectorizers_names = ['CountVectorizer', 'TfidfVectorizer']

# %%
for vectorizer in vectorizers:
    print(f'Embedding: {vectorizers_names[vectorizers.index(vectorizer)]}')
    X_train = vectorizer.fit_transform(training_p[x_label_column])
    y_train = training_p[y_label_column].tolist()
    for j, model in enumerate(models):
        print(f'Model {j}: {model_names[j]}')
        kFold_cv = KFold(n_splits=folds,
                        shuffle=True, 
                        random_state=42)
        param_grid = grid_params
        grid_search = GridSearchCV(model,
                                param_grid[j],
                                cv=kFold_cv.split(X_train, y_train),
                                scoring='f1_macro',
                                verbose=3,
                                return_train_score=True)
        grid_search.fit(X_train, y_train)

        print("Best parameters: ", grid_search.best_params_)
        print("Accuracy :", grid_search.best_score_)
# Out:
# Embedding: CountVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.306, test=0.297) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.316, test=0.306) total time=   0.3s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.302, test=0.293) total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.311, test=0.295) total time=   0.2s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.287, test=0.294) total time=   0.2s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.306, test=0.297) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.316, test=0.306) total time=   0.2s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.302, test=0.293) total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.311, test=0.295) total time=   0.2s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.287, test=0.294) total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.604, test=0.561) total time=   0.4s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.609, test=0.549) total time=   0.4s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.624, test=0.554) total time=   0.3s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.601, test=0.577) total time=   0.4s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.610, test=0.586) total time=   0.3s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.604, test=0.561) total time=   0.4s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.609, test=0.549) total time=   0.3s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.624, test=0.554) total time=   0.4s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.601, test=0.577) total time=   0.4s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.610, test=0.586) total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.857, test=0.723) total time=   0.9s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.852, test=0.730) total time=   0.8s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.849, test=0.741) total time=   0.8s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.848, test=0.734) total time=   0.8s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.849, test=0.736) total time=   0.9s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.857, test=0.723) total time=   0.9s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.852, test=0.730) total time=   0.8s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.849, test=0.741) total time=   0.8s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.848, test=0.734) total time=   0.8s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.849, test=0.736) total time=   0.9s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.979, test=0.731) total time=   1.6s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.976, test=0.748) total time=   1.8s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.974, test=0.763) total time=   1.7s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.975, test=0.753) total time=   1.6s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.975, test=0.748) total time=   1.8s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.979, test=0.731) total time=   1.6s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.976, test=0.748) total time=   1.8s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.974, test=0.763) total time=   1.7s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.975, test=0.753) total time=   1.7s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.975, test=0.748) total time=   1.8s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.709) total time=   2.7s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.742) total time=   3.0s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.759) total time=   2.8s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.737) total time=   2.9s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.994, test=0.725) total time=   3.0s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.709) total time=   2.9s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.742) total time=   3.0s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.759) total time=   2.8s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.737) total time=   2.9s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.725) total time=   3.1s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.687) total time=   3.8s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.723) total time=   4.5s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=   4.3s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=   4.1s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.715) total time=   4.3s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.687) total time=   4.1s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.723) total time=   4.4s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=   4.3s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=   4.1s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.715) total time=   4.5s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=   6.3s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=   6.6s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=   6.4s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.695) total time=   5.0s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.691) total time=   6.3s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=   5.9s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=   6.4s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=   6.6s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.695) total time=   5.3s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.691) total time=   7.0s
# Best parameters:  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7486002438567445
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.291, test=0.269) total time=   0.1s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.289, test=0.286) total time=   0.1s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.271, test=0.268) total time=   0.1s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.268, test=0.261) total time=   0.1s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.287, test=0.292) total time=   0.1s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.264, test=0.257) total time=   0.6s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.264) total time=   0.7s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.261) total time=   0.9s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.261) total time=   0.8s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.271) total time=   0.9s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.267, test=0.259) total time=   1.8s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=   1.6s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.261) total time=   1.4s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.261) total time=   1.5s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.269) total time=   1.7s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.749, test=0.511) total time=   1.1s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.784, test=0.489) total time=   1.2s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.794, test=0.516) total time=   1.2s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.755, test=0.466) total time=   1.1s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.777, test=0.532) total time=   1.1s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.796, test=0.516) total time=   6.5s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.791, test=0.503) total time=   5.9s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.796, test=0.504) total time=   5.7s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.772, test=0.489) total time=   5.9s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.800, test=0.525) total time=   5.9s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.811, test=0.496) total time=  12.2s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.815, test=0.514) total time=  12.4s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.808, test=0.500) total time=  12.0s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.804, test=0.488) total time=  12.1s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.804, test=0.519) total time=  12.2s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.948, test=0.605) total time=   2.1s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.950, test=0.617) total time=   2.2s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.958, test=0.586) total time=   2.2s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.944, test=0.569) total time=   2.1s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.946, test=0.614) total time=   2.2s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.974, test=0.648) total time=  11.1s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.972, test=0.625) total time=  11.2s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.973, test=0.614) total time=  11.2s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.974, test=0.618) total time=  10.9s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.976, test=0.646) total time=  11.2s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.975, test=0.637) total time=  22.4s
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.974, test=0.621) total time=  22.3s
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.975, test=0.614) total time=  22.1s
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.976, test=0.630) total time=  21.7s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.980, test=0.646) total time=  22.6s
# Best parameters:  {'max_depth': 100, 'n_estimators': 50, 'random_state': 42}
# Accuracy : 0.6301185030693685
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.525, test=0.515) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.533, test=0.481) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.530, test=0.490) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.523, test=0.502) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.521, test=0.516) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.525, test=0.515) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.533, test=0.481) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.530, test=0.490) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.523, test=0.502) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.521, test=0.516) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.819, test=0.731) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.814, test=0.720) total time=   0.1s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.815, test=0.728) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.815, test=0.732) total time=   0.1s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.816, test=0.722) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.819, test=0.731) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.814, test=0.720) total time=   0.1s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.815, test=0.728) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.815, test=0.732) total time=   0.1s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.816, test=0.722) total time=   0.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.960, test=0.737) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.957, test=0.753) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.959, test=0.762) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.957, test=0.746) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.957, test=0.749) total time=   0.5s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.960, test=0.737) total time=   0.5s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.957, test=0.753) total time=   0.6s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.959, test=0.762) total time=   0.8s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.957, test=0.746) total time=   0.7s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.957, test=0.749) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.712) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.994, test=0.743) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.994, test=0.757) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.729) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.993, test=0.739) total time=   0.5s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.712) total time=   1.9s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.743) total time=   2.3s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.755) total time=   2.4s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.732) total time=   2.4s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.993, test=0.739) total time=   2.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.670) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.700) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.715) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.706) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.687) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.671) total time=   3.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.702) total time=   3.8s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.709) total time=   3.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.708) total time=   3.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.682) total time=   3.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.638) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.688) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.672) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.670) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.670) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.640) total time=   3.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.684) total time=   4.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.670) total time=   3.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time=   3.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.670) total time=   3.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.990, test=0.624) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.678) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.992, test=0.657) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.670) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.662) total time=   0.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.984, test=0.624) total time=   3.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.976, test=0.638) total time=   3.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.987, test=0.649) total time=   3.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.984, test=0.650) total time=   3.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.970, test=0.634) total time=   3.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters:  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7493244480246294
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.686, test=0.501) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.699, test=0.496) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.681, test=0.495) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.672, test=0.512) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.683, test=0.485) total time=   0.2s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.523) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.522) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.500) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.538) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.498) total time=   0.2s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.5162291058095081
# Embedding: TfidfVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.1s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.2s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.262) total time=   0.1s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.1s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.1s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.258) total time=   0.1s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.262) total time=   0.1s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.257, test=0.255) total time=   0.1s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.258) total time=   0.1s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.476, test=0.442) total time=   0.3s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.473, test=0.440) total time=   0.4s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.467, test=0.432) total time=   0.3s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.469, test=0.450) total time=   0.3s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.467, test=0.440) total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.476, test=0.442) total time=   0.2s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.473, test=0.440) total time=   0.3s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.467, test=0.432) total time=   0.2s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.469, test=0.450) total time=   0.4s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.467, test=0.440) total time=   0.3s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.850, test=0.690) total time=   0.8s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.845, test=0.702) total time=   0.8s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.848, test=0.701) total time=   0.9s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.845, test=0.688) total time=   0.9s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.846, test=0.704) total time=   0.7s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.850, test=0.690) total time=   0.9s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.845, test=0.702) total time=   0.8s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.848, test=0.701) total time=   1.0s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.845, test=0.688) total time=   0.9s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.846, test=0.704) total time=   0.7s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.992, test=0.705) total time=   1.8s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.989, test=0.720) total time=   1.8s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.990, test=0.744) total time=   1.9s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.992, test=0.720) total time=   1.9s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.990, test=0.724) total time=   1.8s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.992, test=0.705) total time=   1.8s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.989, test=0.720) total time=   1.8s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.990, test=0.744) total time=   1.9s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.992, test=0.720) total time=   1.9s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.990, test=0.724) total time=   1.9s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.698) total time=   2.8s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.696) total time=   2.8s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   3.3s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.717) total time=   2.7s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.712) total time=   3.1s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.698) total time=   2.7s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.696) total time=   2.8s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   3.3s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.717) total time=   2.6s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.712) total time=   3.1s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   4.0s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.696) total time=   4.0s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=   4.2s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.701) total time=   4.1s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   4.8s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   4.0s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.696) total time=   4.2s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=   4.1s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.701) total time=   4.1s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   4.7s
# Best parameters:  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7226986296863669
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.343, test=0.333) total time=   0.1s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.279, test=0.272) total time=   0.1s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.275, test=0.270) total time=   0.0s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.271, test=0.264) total time=   0.1s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.286, test=0.278) total time=   0.1s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.266, test=0.257) total time=   0.7s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.261, test=0.264) total time=   0.7s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.265, test=0.261) total time=   0.7s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.261) total time=   0.7s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.269) total time=   0.7s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.267, test=0.259) total time=   1.5s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.264) total time=   1.5s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.259) total time=   1.5s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.261) total time=   1.4s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.267) total time=   1.5s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.765, test=0.495) total time=   1.1s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.791, test=0.495) total time=   1.2s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.747, test=0.485) total time=   1.0s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.785, test=0.495) total time=   1.0s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.781, test=0.551) total time=   1.1s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.811, test=0.531) total time=   5.8s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.810, test=0.507) total time=   5.9s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.797, test=0.463) total time=   5.8s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.821, test=0.490) total time=   5.6s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.822, test=0.542) total time=   5.9s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.816, test=0.495) total time=  11.9s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.819, test=0.479) total time=  12.0s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.805, test=0.471) total time=  11.6s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.828, test=0.482) total time=  11.6s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.817, test=0.533) total time=  11.8s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.947, test=0.591) total time=   1.9s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.956, test=0.582) total time=   2.9s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.958, test=0.605) total time=   2.5s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.951, test=0.563) total time=   2.0s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.952, test=0.587) total time=   2.0s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.977, test=0.616) total time=  10.8s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.978, test=0.595) total time=  10.6s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.982, test=0.612) total time=  10.3s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.984, test=0.592) total time=  10.3s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.981, test=0.615) total time=  10.8s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.981, test=0.616) total time=  20.5s
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.983, test=0.593) total time=  20.7s
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.985, test=0.612) total time=  20.6s
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.989, test=0.595) total time=  20.3s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.984, test=0.621) total time=  20.7s
# Best parameters:  {'max_depth': 100, 'n_estimators': 100, 'random_state': 42}
# Accuracy : 0.6074083041367966
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.354, test=0.349) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.355, test=0.338) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.355, test=0.327) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.350, test=0.336) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.345, test=0.337) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.354, test=0.349) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.355, test=0.338) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.355, test=0.327) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.350, test=0.336) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.345, test=0.337) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.802, test=0.672) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.798, test=0.682) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.792, test=0.680) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.797, test=0.681) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.796, test=0.682) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.802, test=0.672) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.798, test=0.682) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.792, test=0.680) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.797, test=0.681) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.796, test=0.682) total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.985, test=0.717) total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.982, test=0.736) total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.983, test=0.750) total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.985, test=0.736) total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.980, test=0.742) total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.985, test=0.717) total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.982, test=0.736) total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.983, test=0.750) total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.985, test=0.736) total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.980, test=0.742) total time=   0.0s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.696) total time=   0.2s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.708) total time=   0.2s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.730) total time=   0.2s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.709) total time=   0.2s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.724) total time=   0.2s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.696) total time=   0.2s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.708) total time=   0.2s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.730) total time=   0.2s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.709) total time=   0.2s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.724) total time=   0.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.668) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.702) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.693) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.684) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.694) total time=   0.8s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.667) total time=   3.0s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.703) total time=   3.0s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.691) total time=   2.7s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.681) total time=   3.0s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.691) total time=   3.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.656) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.692) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.684) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.660) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.675) total time=   0.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.650) total time=   6.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.696) total time=   6.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   6.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.663) total time=   6.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.674) total time=   6.3s
# Best parameters:  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7363699056755008
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.782, test=0.583) total time=   0.8s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.777, test=0.625) total time=   0.6s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.773, test=0.587) total time=   0.6s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.772, test=0.615) total time=   0.6s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.771, test=0.576) total time=   0.6s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.594) total time=   0.5s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.630) total time=   0.5s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.588) total time=   0.5s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.627) total time=   0.5s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.592) total time=   0.5s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.6060707294847043

# %%
vectorizers = [CountVectorizer(ngram_range = (1,2), lowercase = False), TfidfVectorizer(ngram_range = (1,2), lowercase = False)]
for vectorizer in vectorizers:
    print(f'Embedding: {vectorizers_names[vectorizers.index(vectorizer)]}')
    X_train = vectorizer.fit_transform(training_p[x_label_column])
    y_train = training_p[y_label_column].tolist()
    for j, model in enumerate(models):
        print(f'Model {j}: {model_names[j]}')
        kFold_cv = KFold(n_splits=folds,
                        shuffle=True, 
                        random_state=42)
        param_grid = grid_params
        grid_search = GridSearchCV(model,
                                param_grid[j],
                                cv=kFold_cv.split(X_train, y_train),
                                scoring='f1_macro',
                                verbose=3,
                                return_train_score=True)
        grid_search.fit(X_train, y_train)

        print("Best parameters: ", grid_search.best_params_)
        print("Accuracy :", grid_search.best_score_)
# Out:
# Embedding: CountVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.317, test=0.308) total time=   1.2s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.325, test=0.307) total time=   1.1s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.311, test=0.297) total time=   1.1s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.323, test=0.299) total time=   1.1s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.302, test=0.295) total time=   1.2s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.317, test=0.308) total time=   1.2s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.325, test=0.307) total time=   1.2s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.311, test=0.297) total time=   1.2s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.323, test=0.299) total time=   1.1s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.302, test=0.295) total time=   1.1s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.664, test=0.565) total time=   1.8s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.667, test=0.551) total time=   2.0s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.671, test=0.565) total time=   1.8s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.665, test=0.584) total time=   1.8s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.661, test=0.596) total time=   1.8s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.664, test=0.565) total time=   1.9s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.667, test=0.551) total time=   1.9s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.671, test=0.565) total time=   1.8s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.665, test=0.584) total time=   1.8s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.661, test=0.596) total time=   1.8s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.947, test=0.715) total time=   3.5s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.945, test=0.731) total time=   3.9s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.946, test=0.734) total time=   3.7s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.945, test=0.740) total time=   3.8s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.941, test=0.737) total time=   3.9s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.947, test=0.715) total time=   3.5s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.945, test=0.731) total time=   3.9s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.946, test=0.734) total time=   3.6s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.945, test=0.740) total time=   3.9s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.941, test=0.737) total time=   3.9s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.739) total time=   6.1s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.750) total time=   6.6s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.760) total time=   6.2s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.751) total time=   6.3s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.741) total time=   6.6s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.739) total time=   6.1s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.750) total time=   6.6s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.760) total time=   6.2s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.751) total time=   6.5s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.741) total time=   6.5s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   8.5s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=   9.6s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.758) total time=   8.7s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.754) total time=   8.7s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.745) total time=   8.6s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   8.6s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=   9.5s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.758) total time=   8.8s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.754) total time=   8.7s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.745) total time=   8.5s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=  12.0s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.756) total time=  13.6s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.756) total time=  13.0s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.753) total time=  10.9s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=  12.6s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=  12.1s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.756) total time=  13.6s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.756) total time=  13.0s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.753) total time=  11.1s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=  12.6s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.732) total time=  25.4s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=  27.7s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.755) total time=  24.8s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.746) total time=  12.0s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=  20.2s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.732) total time=  25.3s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=  27.6s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.755) total time=  25.4s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.746) total time=  12.0s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=  19.7s
# Best parameters:  {'C': 100.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.750193626456112
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.264, test=0.257) total time=   0.2s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.261, test=0.264) total time=   0.2s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.274, test=0.266) total time=   0.2s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.299, test=0.285) total time=   0.2s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.264, test=0.260) total time=   0.2s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.257) total time=   1.4s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.261, test=0.264) total time=   1.3s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.266, test=0.262) total time=   1.5s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.261) total time=   1.3s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.257, test=0.260) total time=   1.3s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.257) total time=   2.8s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=   2.8s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.266, test=0.261) total time=   2.9s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.261) total time=   2.7s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.260, test=0.267) total time=   2.8s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.623, test=0.463) total time=   2.0s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.523, test=0.397) total time=   2.0s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.532, test=0.320) total time=   1.9s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.593, test=0.426) total time=   1.9s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.586, test=0.409) total time=   2.1s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.567, test=0.399) total time=  10.8s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.531, test=0.385) total time=  10.8s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.523, test=0.337) total time=  10.3s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.563, test=0.395) total time=  10.2s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.558, test=0.383) total time=  10.6s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.531, test=0.373) total time=  21.3s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.528, test=0.378) total time=  21.2s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.507, test=0.329) total time=  20.8s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.559, test=0.404) total time=  20.7s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.530, test=0.375) total time=  21.3s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.863, test=0.571) total time=   4.3s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.830, test=0.475) total time=   4.2s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.831, test=0.478) total time=   4.0s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.862, test=0.534) total time=   4.1s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.870, test=0.533) total time=   4.3s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.899, test=0.516) total time=  23.3s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.871, test=0.486) total time=  22.2s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.874, test=0.473) total time=  21.6s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.888, test=0.506) total time=  21.1s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.884, test=0.549) total time=  21.5s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.899, test=0.502) total time=  45.0s
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.889, test=0.483) total time=  44.3s
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.874, test=0.466) total time=  43.0s
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.887, test=0.499) total time=  42.1s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.884, test=0.517) total time=  43.7s
# Best parameters:  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# Accuracy : 0.51846750780742
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.561, test=0.526) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.577, test=0.494) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.571, test=0.512) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.560, test=0.514) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.561, test=0.546) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.561, test=0.526) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.577, test=0.494) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.571, test=0.512) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.560, test=0.514) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.561, test=0.546) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.922, test=0.712) total time=   0.2s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.919, test=0.729) total time=   0.3s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.918, test=0.724) total time=   0.3s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.919, test=0.732) total time=   0.3s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.919, test=0.734) total time=   0.3s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.922, test=0.712) total time=   0.2s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.919, test=0.729) total time=   0.3s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.918, test=0.724) total time=   0.3s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.919, test=0.732) total time=   0.3s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.919, test=0.734) total time=   0.3s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.740) total time=   0.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.755) total time=   0.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.765) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.749) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.752) total time=   1.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.740) total time=   0.6s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.755) total time=   1.4s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.765) total time=   1.1s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.749) total time=   1.2s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.752) total time=   1.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.736) total time=   0.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.756) total time=   0.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.752) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=   0.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.747) total time=   1.0s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.736) total time=   1.7s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.757) total time=   2.5s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.752) total time=   2.7s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=   2.7s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.748) total time=   3.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.733) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.738) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=   1.0s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.734) total time=   4.9s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.754) total time=   8.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.738) total time=   6.7s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=   4.9s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.740) total time=   8.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.729) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.749) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.733) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.728) total time=   9.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.751) total time=  10.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.735) total time=   8.8s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.742) total time=   6.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.738) total time=  10.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.727) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.753) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.732) total time=   1.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=   1.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=   1.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.728) total time=  10.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=  10.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.735) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.745) total time=   8.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=  10.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters:  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7522048391548936
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.542, test=0.400) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.551, test=0.380) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.531, test=0.360) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.541, test=0.400) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.547, test=0.388) total time=   0.2s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.420) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.401) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.375) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.419) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.404) total time=   0.2s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.403802092450964
# Embedding: TfidfVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.5s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.5s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.5s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.6s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.6s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.5s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.5s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.5s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.6s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.6s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.7s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.7s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.8s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.8s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.8s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.7s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.8s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.8s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.8s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.9s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.335, test=0.315) total time=   1.3s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.344, test=0.321) total time=   1.4s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.337, test=0.310) total time=   1.5s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.337, test=0.315) total time=   1.5s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.329, test=0.304) total time=   1.5s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.335, test=0.315) total time=   1.3s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.344, test=0.321) total time=   1.5s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.337, test=0.310) total time=   1.5s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.337, test=0.315) total time=   1.5s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.329, test=0.304) total time=   1.5s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.863, test=0.603) total time=   4.0s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.853, test=0.597) total time=   3.5s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.857, test=0.605) total time=   3.5s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.857, test=0.628) total time=   3.6s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.861, test=0.624) total time=   4.0s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.863, test=0.603) total time=   4.0s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.853, test=0.597) total time=   3.6s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.857, test=0.605) total time=   3.5s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.857, test=0.628) total time=   3.6s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.861, test=0.624) total time=   3.9s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   8.1s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.711) total time=   8.4s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   8.0s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=   7.9s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.689) total time=   8.4s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   8.0s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.711) total time=   8.7s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   7.9s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=   8.0s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.689) total time=   8.1s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=  10.5s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=  11.9s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=  11.8s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.727) total time=  11.3s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.713) total time=  12.0s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=  10.4s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=  12.4s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=  11.8s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.727) total time=  11.4s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.713) total time=  11.5s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.694) total time=  16.1s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=  15.3s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=  15.6s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=  15.0s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=  15.0s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.694) total time=  16.0s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=  16.0s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=  15.1s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=  15.4s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=  14.7s
# Best parameters:  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.716991409265956
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.264, test=0.257) total time=   0.2s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.262, test=0.266) total time=   0.2s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.272, test=0.266) total time=   0.2s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.304, test=0.294) total time=   0.2s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.263, test=0.260) total time=   0.2s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.257) total time=   1.5s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.261, test=0.264) total time=   1.5s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.264, test=0.261) total time=   1.6s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.261) total time=   1.4s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.255, test=0.258) total time=   1.5s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.257) total time=   3.0s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=   3.1s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.265, test=0.261) total time=   3.0s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.261) total time=   2.9s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.260, test=0.267) total time=   3.0s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.604, test=0.445) total time=   2.1s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.562, test=0.406) total time=   2.1s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.564, test=0.365) total time=   2.0s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.604, test=0.443) total time=   2.0s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.607, test=0.392) total time=   2.2s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.559, test=0.405) total time=  11.4s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.545, test=0.367) total time=  11.3s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.536, test=0.350) total time=  10.8s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.569, test=0.399) total time=  10.8s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.543, test=0.370) total time=  10.9s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.545, test=0.379) total time=  22.8s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.552, test=0.367) total time=  23.0s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.525, test=0.349) total time=  21.5s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.544, test=0.392) total time=  21.3s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.505, test=0.344) total time=  21.7s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.858, test=0.555) total time=   4.4s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.840, test=0.489) total time=   4.3s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.860, test=0.498) total time=   4.1s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.848, test=0.518) total time=   4.2s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.864, test=0.506) total time=   4.5s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.893, test=0.523) total time=  22.8s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.893, test=0.482) total time=  22.3s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.897, test=0.488) total time=  22.3s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.896, test=0.474) total time=  22.5s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.898, test=0.485) total time=  22.2s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.900, test=0.495) total time=  45.8s
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.906, test=0.479) total time=  45.2s
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.903, test=0.486) total time=  44.4s
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.894, test=0.472) total time=  42.9s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.908, test=0.495) total time=  44.2s
# Best parameters:  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# Accuracy : 0.5129849927670744
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.270, test=0.263) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.270, test=0.274) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.271, test=0.262) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.272, test=0.262) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.267, test=0.269) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.270, test=0.263) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.270, test=0.274) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.271, test=0.262) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.272, test=0.262) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.267, test=0.269) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.759, test=0.560) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.756, test=0.564) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.761, test=0.560) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.754, test=0.572) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.761, test=0.562) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.759, test=0.560) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.756, test=0.564) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.761, test=0.560) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.754, test=0.572) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.761, test=0.562) total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.730) total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.720) total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.723) total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.714) total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   0.0s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.730) total time=   0.0s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.720) total time=   0.0s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.723) total time=   0.0s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.714) total time=   0.0s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time=   0.5s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   0.5s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.731) total time=   0.5s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.736) total time=   0.5s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=   0.5s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time=   0.5s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   0.5s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.731) total time=   0.5s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.736) total time=   0.5s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=   0.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.707) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.727) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.732) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=   1.7s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.707) total time=   5.7s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.738) total time=   5.6s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.728) total time=   4.5s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.732) total time=   4.5s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=   5.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.709) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.736) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.729) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.709) total time=  17.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=  17.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=  15.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.733) total time=  14.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.729) total time=  17.5s
# Best parameters:  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7298221323032593
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.783, test=0.593) total time=   1.8s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.781, test=0.588) total time=   1.8s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.782, test=0.568) total time=   1.8s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.773, test=0.612) total time=   1.8s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.776, test=0.587) total time=   1.9s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.611) total time=   1.7s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.592) total time=   1.8s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.577) total time=   1.8s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.617) total time=   1.8s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.598) total time=   1.9s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.5990804907842111

# %%
vectorizers = [CountVectorizer(ngram_range = (1,3), lowercase = False), TfidfVectorizer(ngram_range = (1,3), lowercase = False)]
for vectorizer in vectorizers:
    print(f'Embedding: {vectorizers_names[vectorizers.index(vectorizer)]}')
    X_train = vectorizer.fit_transform(training_p[x_label_column])
    y_train = training_p[y_label_column].tolist()
    for j, model in enumerate(models):
        print(f'Model {j}: {model_names[j]}')
        kFold_cv = KFold(n_splits=folds,
                        shuffle=True, 
                        random_state=42)
        param_grid = grid_params
        grid_search = GridSearchCV(model,
                                param_grid[j],
                                cv=kFold_cv.split(X_train, y_train),
                                scoring='f1_macro',
                                verbose=3,
                                return_train_score=True)
        grid_search.fit(X_train, y_train)

        print("Best parameters: ", grid_search.best_params_)
        print("Accuracy :", grid_search.best_score_)
# Out:
# Embedding: CountVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.326, test=0.300) total time=   2.7s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.334, test=0.314) total time=   2.6s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.318, test=0.294) total time=   2.5s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.331, test=0.306) total time=   2.7s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.305, test=0.293) total time=   2.5s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.326, test=0.300) total time=   2.8s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.334, test=0.314) total time=   2.6s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.318, test=0.294) total time=   2.7s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.331, test=0.306) total time=   2.5s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.305, test=0.293) total time=   2.7s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.708, test=0.564) total time=   4.3s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.711, test=0.547) total time=   4.5s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.711, test=0.558) total time=   3.9s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.705, test=0.575) total time=   4.2s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.708, test=0.591) total time=   4.3s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.708, test=0.564) total time=   4.4s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.711, test=0.547) total time=   4.3s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.711, test=0.558) total time=   4.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.705, test=0.575) total time=   4.3s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.708, test=0.591) total time=   4.3s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.972, test=0.711) total time=   8.6s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.971, test=0.726) total time=   8.5s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.971, test=0.726) total time=   7.8s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.970, test=0.727) total time=   7.9s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.971, test=0.725) total time=   7.5s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.972, test=0.711) total time=   8.5s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.971, test=0.726) total time=   8.2s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.971, test=0.726) total time=   7.6s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.970, test=0.727) total time=   8.0s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.971, test=0.725) total time=   7.4s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  12.0s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.751) total time=  12.5s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=  13.1s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=  12.3s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=  12.4s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  12.5s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.751) total time=  13.0s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=  12.9s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=  12.8s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=  12.8s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.743) total time=  15.8s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.750) total time=  17.9s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.745) total time=  16.1s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.745) total time=  17.2s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=  16.5s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.743) total time=  15.4s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.750) total time=  17.7s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.745) total time=  16.4s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.745) total time=  17.2s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=  16.8s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=  27.3s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.759) total time=  29.3s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.739) total time=  26.8s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.746) total time=  20.5s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.747) total time=  25.7s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=  27.8s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.759) total time=  28.7s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.739) total time=  28.0s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.746) total time=  20.5s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.747) total time=  25.6s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.732) total time= 1.0min
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.758) total time= 1.0min
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.738) total time=  59.7s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=  24.8s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.745) total time=  45.1s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.732) total time= 1.0min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.758) total time= 1.1min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.738) total time= 1.0min
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.744) total time=  23.3s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.745) total time=  45.3s
# Best parameters:  {'C': 100.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7463184006778151
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.269, test=0.259) total time=   0.3s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.262, test=0.264) total time=   0.3s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.262, test=0.261) total time=   0.3s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.266, test=0.266) total time=   0.3s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.267, test=0.269) total time=   0.3s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.267, test=0.257) total time=   2.0s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.261, test=0.264) total time=   2.6s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.259) total time=   2.0s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.261) total time=   2.0s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.264, test=0.269) total time=   1.9s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.265, test=0.257) total time=   4.1s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=   4.7s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.259) total time=   4.0s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.261) total time=   4.0s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.269) total time=   4.1s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.441, test=0.338) total time=   2.8s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.468, test=0.342) total time=   2.7s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.476, test=0.349) total time=   2.7s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.452, test=0.336) total time=   2.4s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.487, test=0.377) total time=   2.9s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.400, test=0.320) total time=  14.4s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.436, test=0.318) total time=  15.3s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.436, test=0.301) total time=  14.8s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.401, test=0.294) total time=  13.4s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.386, test=0.306) total time=  14.3s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.399, test=0.312) total time=  29.5s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.412, test=0.318) total time=  29.4s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.423, test=0.307) total time=  29.7s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.393, test=0.291) total time=  27.3s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.393, test=0.306) total time=  28.4s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.748, test=0.473) total time=   5.9s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.743, test=0.436) total time=   5.8s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.757, test=0.438) total time=   5.7s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.719, test=0.423) total time=   5.2s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.779, test=0.455) total time=   6.3s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.735, test=0.420) total time=  30.1s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.782, test=0.422) total time=  31.3s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.786, test=0.410) total time=  30.9s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.745, test=0.396) total time=  28.2s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.770, test=0.398) total time=  31.3s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.759, test=0.421) total time= 1.0min
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.776, test=0.418) total time= 1.0min
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.790, test=0.409) total time= 1.0min
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.779, test=0.400) total time=  57.7s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.774, test=0.409) total time= 1.0min
# Best parameters:  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# Accuracy : 0.44486189282659955
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.595, test=0.528) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.609, test=0.494) total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.602, test=0.505) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.589, test=0.513) total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.600, test=0.545) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.595, test=0.528) total time=   0.1s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.609, test=0.494) total time=   0.1s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.602, test=0.505) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.589, test=0.513) total time=   0.1s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.600, test=0.545) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.957, test=0.716) total time=   0.4s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.956, test=0.730) total time=   0.6s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.954, test=0.726) total time=   0.7s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.954, test=0.731) total time=   0.5s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.953, test=0.726) total time=   0.7s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.957, test=0.716) total time=   0.4s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.956, test=0.730) total time=   0.6s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.954, test=0.726) total time=   0.7s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.954, test=0.731) total time=   0.4s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.953, test=0.726) total time=   0.6s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.742) total time=   0.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.755) total time=   1.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.762) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.753) total time=   1.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.756) total time=   1.7s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.742) total time=   0.8s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.755) total time=   2.5s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.762) total time=   2.1s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.753) total time=   1.9s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.756) total time=   3.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   1.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.763) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.749) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.742) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=   1.8s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.737) total time=   2.0s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.763) total time=   3.9s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.749) total time=   3.8s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.743) total time=   3.7s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.752) total time=   4.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.754) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.734) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.739) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.740) total time=   1.8s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.727) total time=  10.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=  15.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.734) total time=  12.1s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.740) total time=   9.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.740) total time=  13.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.729) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.751) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=   1.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.727) total time=  15.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.753) total time=  16.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.727) total time=  14.9s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.741) total time=  10.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.736) total time=  16.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.728) total time=   2.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.755) total time=   2.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.725) total time=   1.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.743) total time=   1.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.738) total time=   2.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.729) total time=  18.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.753) total time=  18.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.725) total time=  14.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.743) total time=  14.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.736) total time=  17.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters:  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7537197811879056
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.503, test=0.354) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.512, test=0.336) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.492, test=0.311) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.508, test=0.350) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.511, test=0.344) total time=   0.2s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.378) total time=   0.2s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.363) total time=   0.2s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.322) total time=   0.2s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.372) total time=   0.2s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.360) total time=   0.2s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.3589829349139793
# Embedding: TfidfVectorizer
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.4s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   1.2s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.4s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.3s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   1.3s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.2s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   1.4s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.3s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.4s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   1.1s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.9s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   1.7s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.8s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.6s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   1.8s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.7s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   1.8s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.6s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   1.8s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   1.7s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.289, test=0.275) total time=   3.5s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.290, test=0.294) total time=   3.3s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.296, test=0.278) total time=   3.0s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.291, test=0.283) total time=   3.3s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.289, test=0.289) total time=   3.6s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.289, test=0.275) total time=   3.4s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.290, test=0.294) total time=   3.3s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.296, test=0.278) total time=   3.1s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.291, test=0.283) total time=   3.3s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.289, test=0.289) total time=   3.7s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.842, test=0.541) total time=   7.7s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.833, test=0.529) total time=   8.7s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.841, test=0.537) total time=   8.0s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.838, test=0.533) total time=   9.2s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.844, test=0.549) total time=   8.2s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.842, test=0.541) total time=   7.9s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.833, test=0.529) total time=   8.6s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.841, test=0.537) total time=   8.1s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.838, test=0.533) total time=   8.9s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.844, test=0.549) total time=   8.3s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.644) total time=  16.9s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.653) total time=  16.7s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.645) total time=  15.4s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.669) total time=  17.4s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.661) total time=  16.5s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.644) total time=  17.1s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.653) total time=  16.8s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.645) total time=  15.4s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.669) total time=  17.0s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.661) total time=  15.8s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.659) total time=  25.3s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.702) total time=  26.8s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time=  24.4s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.687) total time=  22.8s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.683) total time=  26.2s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.659) total time=  23.7s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.702) total time=  23.8s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time=  24.1s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.687) total time=  23.0s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.683) total time=  26.0s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.669) total time=  30.4s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.704) total time=  34.9s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.685) total time=  27.8s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.698) total time=  30.7s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.690) total time=  32.0s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.669) total time=  30.4s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.704) total time=  35.4s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.685) total time=  27.9s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.698) total time=  31.0s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.690) total time=  31.9s
# Best parameters:  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.6891016244172773
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.269, test=0.257) total time=   0.3s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.262, test=0.264) total time=   0.3s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.264, test=0.259) total time=   0.3s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.263, test=0.261) total time=   0.4s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.266, test=0.269) total time=   0.4s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.267, test=0.257) total time=   2.2s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.261, test=0.264) total time=   2.5s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.259) total time=   2.3s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.261) total time=   2.1s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.269) total time=   2.1s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.257) total time=   4.6s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=   4.7s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.259) total time=   4.5s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.261) total time=   4.1s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.269) total time=   4.7s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.478, test=0.343) total time=   3.3s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.467, test=0.372) total time=   2.9s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.525, test=0.390) total time=   3.0s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.461, test=0.332) total time=   3.2s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.489, test=0.379) total time=   3.0s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.413, test=0.315) total time=  16.2s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.447, test=0.333) total time=  16.7s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.453, test=0.313) total time=  15.9s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.436, test=0.320) total time=  15.1s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.432, test=0.332) total time=  15.3s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.409, test=0.318) total time=  32.7s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.425, test=0.330) total time=  32.5s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.450, test=0.316) total time=  32.5s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.428, test=0.303) total time=  29.9s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.423, test=0.323) total time=  31.4s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.773, test=0.410) total time=   6.5s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.762, test=0.436) total time=   6.5s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.774, test=0.434) total time=   6.1s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.747, test=0.413) total time=   6.1s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.756, test=0.454) total time=   6.2s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.802, test=0.396) total time=  32.6s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.821, test=0.427) total time=  33.7s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.825, test=0.419) total time=  32.4s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.796, test=0.401) total time=  31.2s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.792, test=0.431) total time=  32.3s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.821, test=0.400) total time= 1.1min
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.844, test=0.410) total time= 1.1min
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.820, test=0.400) total time= 1.1min
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.812, test=0.419) total time= 1.1min
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.792, test=0.425) total time= 1.1min
# Best parameters:  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# Accuracy : 0.4294202204951338
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   0.0s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   0.0s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.260, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.258, test=0.262) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.260, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.259, test=0.259) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.257, test=0.260) total time=   0.0s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.260, test=0.255) total time=   0.0s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.258, test=0.262) total time=   0.0s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.260, test=0.255) total time=   0.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.259, test=0.259) total time=   0.0s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.257, test=0.260) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.680, test=0.477) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.694, test=0.480) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.694, test=0.475) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.685, test=0.475) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.697, test=0.481) total time=   0.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.680, test=0.477) total time=   0.0s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.694, test=0.480) total time=   0.0s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.694, test=0.475) total time=   0.0s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.685, test=0.475) total time=   0.0s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.697, test=0.481) total time=   0.0s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.664) total time=   0.1s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   0.1s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.670) total time=   0.1s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   0.1s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.671) total time=   0.1s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.664) total time=   0.1s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   0.1s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.670) total time=   0.1s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   0.1s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.671) total time=   0.1s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=   1.1s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time=   1.0s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.706) total time=   1.1s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.717) total time=   1.4s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   1.5s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=   1.2s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time=   1.5s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.706) total time=   0.9s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.717) total time=   0.9s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=   1.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.686) total time=   3.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.715) total time=   3.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.707) total time=   3.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=   3.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.704) total time=   3.4s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.686) total time=   9.3s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.715) total time=   9.1s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.707) total time=   7.0s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=   7.0s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.704) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=   3.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=   3.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.708) total time=   3.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.717) total time=   3.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.703) total time=   3.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.687) total time=  30.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=  28.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.706) total time=  21.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.718) total time=  22.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.704) total time=  27.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Best parameters:  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# Accuracy : 0.7072538338806782
# Model 3: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.783, test=0.596) total time=   3.3s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.775, test=0.601) total time=   3.3s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.771, test=0.593) total time=   3.3s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.772, test=0.620) total time=   3.4s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.775, test=0.596) total time=   3.6s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.610) total time=   3.4s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.606) total time=   3.4s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.607) total time=   3.5s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.623) total time=   3.4s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.605) total time=   3.6s
# Best parameters:  {'n_neighbors': 3, 'weights': 'distance'}
# Accuracy : 0.6102056412000244

# %% [markdown]
# ## Finding best hyperparams (TP-LPTO)

# %%
models = [LogisticRegression(), RandomForestClassifier(), LinearSVC(), MultinomialNB(), KNeighborsClassifier()]
model_names = ['Regresión logística', 'Random Forest', 'SVM Lineal', 'NB Multinomial', 'KNN']
x_label_column = 'tweets'
y_label_column = 'label'
folds = 5
grid_params  = [{"C":np.logspace(-3,3,7), "penalty":["l2"], "max_iter": [1000, 10000], "random_state":[42]},
                {"n_estimators": [10, 50, 100], "max_depth":[10, 50, 100], "random_state": [42]},
                {"C":np.logspace(-3,3,7), "penalty":["l2"], "max_iter": [1000, 10000], "random_state":[42]},
                {},
                {"n_neighbors":[3], "weights":['uniform', 'distance']}]
path_to_save_models = ''
path_to_save_vectorizers = ''

# %%
for i in range(2):
  if i == 0:
    print('Count vectorizer')
    vectorizer = CountVectorizer(ngram_range = (1,1), lowercase = False)
    oth_feats_vectorizer = CountVectorizer(ngram_range = (1,1), lowercase = False)
  else:
    print('TF-IDF')
    vectorizer = TfidfVectorizer(ngram_range = (1,1), lowercase = False)
    oth_feats_vectorizer = TfidfVectorizer(ngram_range = (1,1), lowercase = False)

  ml_homo = rcm.RobustMachineLearningModel(models=models,
                                       model_names=model_names,
                                       train_data=training_p,
                                       x_label_column=x_label_column,
                                       y_label_column=y_label_column,
                                       folds=folds,
                                       grid_params=grid_params,
                                       path_to_save_models=path_to_save_models,
                                       path_to_save_vectorizer=path_to_save_vectorizers,
                                       lemma=True,
                                       pos=True,
                                       tag=True,
                                       other_features=True,
                                       vectorizer=vectorizer,
                                       oth_feats_vectorizer=oth_feats_vectorizer,
                                       language='es')
  ml_homo.get_best_cross_validation()
# Out:
# n-gram range: (1, 1)
# Count vectorizer
# /usr/local/lib/python3.9/dist-packages/spacy/util.py:887: UserWarning: [W095] Model 'es_core_news_sm' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.5.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   model (Model): The parent model.
# Lemma: (7000, 13822)
# POS: (7000, 16)
# TAG: (7000, 15)
# Other features: (7000, 760)
# Final vector shape: (7000, 14613)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.335, test=0.331) total time=  26.6s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.348, test=0.336) total time=  26.2s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.329, test=0.307) total time=  25.0s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.342, test=0.340) total time=  24.1s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.327, test=0.323) total time=  24.1s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.335, test=0.331) total time=  27.2s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.348, test=0.336) total time=  23.1s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.329, test=0.307) total time=  23.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.342, test=0.340) total time=  25.3s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.327, test=0.323) total time=  23.3s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.661, test=0.591) total time=  51.4s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.666, test=0.597) total time=  54.4s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.657, test=0.620) total time=  51.7s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.661, test=0.585) total time=  53.3s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.658, test=0.627) total time=  52.5s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.661, test=0.591) total time=  49.9s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.666, test=0.597) total time=  54.1s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.657, test=0.620) total time=  52.3s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.661, test=0.585) total time=  53.1s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.658, test=0.627) total time=  52.6s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.867, test=0.719) total time= 1.8min
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.861, test=0.718) total time= 2.0min
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.863, test=0.714) total time= 1.9min
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.861, test=0.713) total time= 1.9min
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.865, test=0.711) total time= 1.9min
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.867, test=0.719) total time= 1.8min
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.861, test=0.718) total time= 2.0min
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.863, test=0.714) total time= 1.9min
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.861, test=0.713) total time= 1.8min
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.865, test=0.711) total time= 1.9min
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.984, test=0.716) total time= 3.4min
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.980, test=0.728) total time= 3.5min
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.982, test=0.727) total time= 3.4min
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.981, test=0.723) total time= 3.7min
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.983, test=0.717) total time= 3.5min
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.984, test=0.716) total time= 3.4min
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.980, test=0.728) total time= 3.6min
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.982, test=0.727) total time= 3.4min
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.981, test=0.723) total time= 3.7min
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.983, test=0.717) total time= 3.5min
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.698) total time= 5.1min
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.712) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time= 5.5min
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time= 5.3min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.716) total time= 5.5min
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.698) total time= 5.0min
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.712) total time= 5.4min
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time= 5.5min
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time= 5.3min
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.716) total time= 5.9min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.682) total time= 5.5min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time= 5.5min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.709) total time= 5.5min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.698) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.695) total time= 5.5min
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.682) total time= 6.4min
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.698) total time= 7.5min
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.709) total time= 6.2min
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.699) total time= 6.8min
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.695) total time= 7.3min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.680) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.694) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.690) total time= 5.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.682) total time= 5.4min
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.679) total time= 9.3min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time= 9.7min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.695) total time= 9.0min
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.691) total time= 8.2min
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.678) total time= 9.7min
# tuned hpyerparameters :(best parameters)  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.7221968716840138
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.301, test=0.276) total time=   1.1s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.321, test=0.319) total time=   1.0s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.285, test=0.268) total time=   1.0s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.304, test=0.280) total time=   1.0s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.271, test=0.273) total time=   1.0s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.267, test=0.257) total time=   3.2s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.275, test=0.278) total time=   3.2s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.267, test=0.261) total time=   3.2s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.279, test=0.264) total time=   3.2s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.269, test=0.269) total time=   3.3s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.266, test=0.259) total time=   6.0s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.266, test=0.266) total time=   5.8s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.265, test=0.259) total time=   5.9s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.272, test=0.261) total time=   5.8s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.260, test=0.267) total time=   5.9s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.919, test=0.528) total time=   2.2s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.927, test=0.498) total time=   2.2s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.924, test=0.524) total time=   2.2s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.923, test=0.543) total time=   2.2s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.923, test=0.487) total time=   2.2s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.967, test=0.490) total time=   9.2s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.971, test=0.495) total time=   9.2s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.972, test=0.516) total time=   9.0s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.962, test=0.478) total time=   9.2s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.975, test=0.497) total time=   9.0s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.974, test=0.476) total time=  17.8s
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.981, test=0.506) total time=  17.8s
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.974, test=0.491) total time=  18.0s
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.969, test=0.492) total time=  18.2s
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.982, test=0.491) total time=  17.7s
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.983, test=0.529) total time=   2.5s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.981, test=0.505) total time=   2.7s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.987, test=0.521) total time=   2.6s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.984, test=0.530) total time=   2.6s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.982, test=0.546) total time=   2.5s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.514) total time=  10.7s
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.516) total time=  10.3s
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=1.000, test=0.538) total time=  10.7s
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.523) total time=  10.8s
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.541) total time=  10.4s
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.514) total time=  20.9s
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.526) total time=  20.8s
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.533) total time=  21.9s
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.512) total time=  21.3s
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.531) total time=  20.9s
# tuned hpyerparameters :(best parameters)  {'max_depth': 100, 'n_estimators': 50, 'random_state': 42}
# accuracy : 0.5264474330357535
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.577, test=0.508) total time=   1.3s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.572, test=0.520) total time=   1.3s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.569, test=0.534) total time=   1.3s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.576, test=0.513) total time=   1.3s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.558, test=0.547) total time=   1.3s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.577, test=0.508) total time=   1.3s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.572, test=0.520) total time=   1.3s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.569, test=0.534) total time=   1.2s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.576, test=0.513) total time=   1.3s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.558, test=0.547) total time=   1.3s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.832, test=0.726) total time=   2.6s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.828, test=0.708) total time=   2.4s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.831, test=0.711) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.826, test=0.713) total time=   2.7s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.831, test=0.711) total time=   2.6s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.832, test=0.726) total time=   2.6s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.828, test=0.708) total time=   2.4s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.831, test=0.711) total time=   2.4s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.826, test=0.713) total time=   2.7s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.831, test=0.711) total time=   2.6s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.965, test=0.734) total time=   2.7s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.959, test=0.730) total time=   2.9s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.964, test=0.756) total time=   2.8s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.967, test=0.725) total time=   2.7s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.964, test=0.718) total time=   2.8s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.965, test=0.734) total time=   7.1s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.960, test=0.730) total time=   7.2s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.965, test=0.758) total time=   6.3s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.966, test=0.725) total time=   6.5s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.964, test=0.718) total time=   6.2s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   2.5s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.702) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.721) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.708) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.997, test=0.694) total time=   2.5s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.694) total time=   6.6s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.701) total time=  10.6s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.722) total time=   9.2s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.708) total time=  11.5s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.997, test=0.696) total time=  11.2s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.666) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.684) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.682) total time=   2.5s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.998, test=0.672) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.667) total time=  10.0s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.683) total time=  12.1s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.691) total time=  11.6s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.681) total time=  11.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.673) total time=  11.9s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.655) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.671) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.672) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.675) total time=   2.5s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.655) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.663) total time=  11.0s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.669) total time=  11.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.666) total time=  11.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=  11.1s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.998, test=0.647) total time=  11.0s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.660) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.672) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.670) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.671) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.647) total time=   2.6s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.993, test=0.657) total time=  11.0s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.662) total time=  11.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.660) total time=  11.1s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.640) total time=  10.9s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.637) total time=  10.9s
# tuned hpyerparameters :(best parameters)  {'C': 0.1, 'max_iter': 10000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.7330444551839149
# Model 3: NB Multinomial
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..............., score=(train=0.741, test=0.602) total time=   1.7s
# [CV 2/5] END ..............., score=(train=0.736, test=0.612) total time=   1.8s
# [CV 3/5] END ..............., score=(train=0.738, test=0.607) total time=   1.7s
# [CV 4/5] END ..............., score=(train=0.735, test=0.615) total time=   1.8s
# [CV 5/5] END ..............., score=(train=0.743, test=0.614) total time=   1.7s
# tuned hpyerparameters :(best parameters)  {}
# accuracy : 0.6099182209230831
# Model 4: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.675, test=0.435) total time=   4.5s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.672, test=0.463) total time=   4.5s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.670, test=0.435) total time=   5.2s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.678, test=0.419) total time=   6.8s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.675, test=0.445) total time=   5.6s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.438) total time=   4.5s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.457) total time=   4.5s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.453) total time=   4.5s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.428) total time=   5.7s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.440) total time=   6.5s
# tuned hpyerparameters :(best parameters)  {'n_neighbors': 3, 'weights': 'distance'}
# accuracy : 0.4431868369439103
# TF-IDF
# /usr/local/lib/python3.9/dist-packages/spacy/util.py:887: UserWarning: [W095] Model 'es_core_news_sm' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.5.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   model (Model): The parent model.
# Lemma: (7000, 13822)
# POS: (7000, 16)
# TAG: (7000, 15)
# Other features: (7000, 760)
# Final vector shape: (7000, 14613)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.4s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   5.7s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.4s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.0s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   5.4s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.9s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   4.2s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.3s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   5.5s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   4.6s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.272, test=0.260) total time=   9.5s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.272, test=0.284) total time=   9.0s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.271, test=0.268) total time=   8.4s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.272, test=0.270) total time=   9.2s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.272, test=0.263) total time=   9.3s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.272, test=0.260) total time=   9.8s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.272, test=0.284) total time=   8.3s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.271, test=0.268) total time=   9.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.272, test=0.270) total time=   8.8s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.272, test=0.263) total time=   9.4s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.561, test=0.507) total time=  22.2s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.559, test=0.503) total time=  20.4s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.565, test=0.494) total time=  21.2s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.569, test=0.477) total time=  22.3s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.565, test=0.530) total time=  19.8s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.561, test=0.507) total time=  22.0s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.559, test=0.503) total time=  20.6s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.565, test=0.494) total time=  20.3s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.569, test=0.477) total time=  22.9s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.565, test=0.530) total time=  19.9s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.877, test=0.668) total time=  45.4s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.870, test=0.663) total time=  49.0s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.874, test=0.680) total time=  52.0s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.874, test=0.676) total time=  46.3s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.868, test=0.679) total time=  46.9s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.877, test=0.668) total time=  45.7s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.870, test=0.663) total time=  48.4s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.874, test=0.680) total time=  53.1s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.874, test=0.676) total time=  46.3s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.868, test=0.679) total time=  45.5s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.996, test=0.675) total time= 1.5min
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.994, test=0.700) total time= 1.6min
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.698) total time= 1.5min
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.995, test=0.689) total time= 1.6min
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.994, test=0.703) total time= 1.7min
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.996, test=0.675) total time= 1.6min
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.700) total time= 1.7min
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.698) total time= 1.5min
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.995, test=0.689) total time= 1.6min
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.994, test=0.703) total time= 1.7min
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.681) total time= 2.5min
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.692) total time= 2.7min
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.688) total time= 2.3min
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.686) total time= 2.4min
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.693) total time= 2.7min
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.681) total time= 2.6min
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.692) total time= 2.7min
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.688) total time= 2.3min
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.686) total time= 2.5min
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.693) total time= 2.7min
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.670) total time= 3.3min
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.688) total time= 3.5min
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time= 3.4min
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.689) total time= 3.3min
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.677) total time= 3.7min
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.670) total time= 3.3min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.688) total time= 3.5min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time= 3.4min
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.689) total time= 3.3min
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.677) total time= 3.7min
# tuned hpyerparameters :(best parameters)  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.6930300291116622
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.292, test=0.269) total time=   1.1s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.347, test=0.302) total time=   1.1s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.310, test=0.287) total time=   1.1s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.331, test=0.285) total time=   1.0s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.297, test=0.289) total time=   1.1s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.265, test=0.257) total time=   3.3s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.280, test=0.274) total time=   3.3s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.278, test=0.270) total time=   3.3s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.277, test=0.266) total time=   3.4s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.273, test=0.269) total time=   3.3s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.264, test=0.257) total time=   6.1s
# ...
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.668) total time=  12.2s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.647) total time=  14.2s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.656) total time=   2.5s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.668) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.648) total time=   2.3s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.661) total time=   2.2s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.643) total time=   2.4s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.656) total time=  14.7s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.673) total time=  14.8s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.654) total time=  13.6s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.661) total time=  14.7s
# /usr/local/lib/python3.9/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.638) total time=  14.5s
# tuned hpyerparameters :(best parameters)  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.7015631730644489
# Model 3: NB Multinomial
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..............., score=(train=0.369, test=0.311) total time=   0.6s
# [CV 2/5] END ..............., score=(train=0.373, test=0.327) total time=   0.6s
# [CV 3/5] END ..............., score=(train=0.365, test=0.318) total time=   0.7s
# [CV 4/5] END ..............., score=(train=0.370, test=0.321) total time=   0.5s
# [CV 5/5] END ..............., score=(train=0.367, test=0.323) total time=   0.5s
# tuned hpyerparameters :(best parameters)  {}
# accuracy : 0.3199280850767515
# Model 4: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.682, test=0.401) total time=   4.7s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.680, test=0.448) total time=   4.4s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.675, test=0.437) total time=   4.4s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.689, test=0.421) total time=   5.1s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.694, test=0.441) total time=   5.6s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.404) total time=   4.4s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.447) total time=   4.3s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.447) total time=   4.3s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.415) total time=   5.3s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.438) total time=   5.6s
# tuned hpyerparameters :(best parameters)  {'n_neighbors': 3, 'weights': 'distance'}
# accuracy : 0.4302301832163333
# n-gram range: (1, 2)
# Count vectorizer
# /usr/local/lib/python3.9/dist-packages/spacy/util.py:887: UserWarning: [W095] Model 'es_core_news_sm' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.5.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   model (Model): The parent model.
# Lemma: (7000, 79388)
# POS: (7000, 216)
# TAG: (7000, 204)
# Other features: (7000, 7304)
# Final vector shape: (7000, 87112)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.385, test=0.365) total time= 2.2min
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.390, test=0.361) total time= 2.3min
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.382, test=0.347) total time= 2.0min
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.384, test=0.368) total time= 2.5min
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.369, test=0.372) total time= 2.2min
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.385, test=0.365) total time= 2.2min
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.390, test=0.361) total time= 2.3min
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.382, test=0.347) total time= 2.0min
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.384, test=0.368) total time= 2.6min
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.369, test=0.372) total time= 2.3min
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.735, test=0.612) total time= 4.3min
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.732, test=0.606) total time= 4.3min
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.742, test=0.622) total time= 4.5min
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.733, test=0.595) total time= 4.5min
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.734, test=0.635) total time= 4.7min
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.735, test=0.612) total time= 4.3min
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.732, test=0.606) total time= 4.4min
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.742, test=0.622) total time= 4.4min
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.733, test=0.595) total time= 4.5min
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.734, test=0.635) total time= 4.7min
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.970, test=0.694) total time= 9.7min
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.967, test=0.702) total time=10.5min
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.968, test=0.694) total time= 9.0min
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.967, test=0.693) total time= 8.8min
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.968, test=0.701) total time= 9.6min
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.970, test=0.694) total time= 9.7min
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.967, test=0.702) total time=10.4min
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.968, test=0.694) total time= 9.0min
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.967, test=0.693) total time= 8.6min
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.968, test=0.701) total time= 9.5min
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=14.1min
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=15.1min
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.706) total time=14.2min
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.720) total time=14.2min
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=15.2min
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=14.2min
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=15.1min
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.706) total time=13.9min
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.720) total time=14.2min
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=15.6min
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=19.7min
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.706) total time=19.9min
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=18.7min
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.710) total time=17.9min
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.723) total time=18.9min
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.705) total time=18.7min
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.706) total time=20.6min
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=19.1min
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.710) total time=18.3min
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.723) total time=18.7min
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.701) total time=24.6min
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=27.6min
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.710) total time=26.9min
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.707) total time=21.6min
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=24.7min
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.701) total time=25.3min
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.710) total time=25.3min
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.710) total time=27.6min
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.707) total time=21.6min
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=24.2min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.701) total time=26.2min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time=26.4min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.712) total time=29.0min
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.704) total time=28.9min
# /usr/local/lib/python3.9/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.721) total time=31.6min
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.701) total time=35.5min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.708) total time=40.2min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=39.1min

# %%
for i in range(2):
  if i == 0:
    print('Count vectorizer')
    vectorizer = CountVectorizer(ngram_range = (1,2), lowercase = False)
    oth_feats_vectorizer = CountVectorizer(ngram_range = (1,2), lowercase = False)
  else:
    print('TF-IDF')
    vectorizer = TfidfVectorizer(ngram_range = (1,2), lowercase = False)
    oth_feats_vectorizer = TfidfVectorizer(ngram_range = (1,2), lowercase = False)

  ml_homo = rcm.RobustMachineLearningModel(models=models,
                                       model_names=model_names,
                                       train_data=training_p,
                                       x_label_column=x_label_column,
                                       y_label_column=y_label_column,
                                       folds=folds,
                                       grid_params=grid_params,
                                       path_to_save_models=path_to_save_models,
                                       path_to_save_vectorizer=path_to_save_vectorizers,
                                       lemma=True,
                                       pos=True,
                                       tag=True,
                                       other_features=True,
                                       vectorizer=vectorizer,
                                       oth_feats_vectorizer=oth_feats_vectorizer,
                                       language='es')
  ml_homo.get_best_cross_validation()
# Out:
# Count vectorizer
# Lemma: (7000, 79502)
# POS: (7000, 218)
# TAG: (7000, 200)
# Other features: (7000, 7304)
# Final vector shape: (7000, 87224)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.387, test=0.368) total time= 1.1min
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.397, test=0.362) total time= 1.3min
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.379, test=0.338) total time= 1.1min
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.388, test=0.377) total time= 1.2min
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.366, test=0.364) total time= 1.2min
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.387, test=0.368) total time= 1.2min
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.397, test=0.362) total time= 1.2min
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.379, test=0.338) total time= 1.1min
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.388, test=0.377) total time= 1.1min
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.366, test=0.364) total time= 1.2min
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.736, test=0.599) total time= 2.0min
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.728, test=0.605) total time= 2.4min
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.735, test=0.620) total time= 2.1min
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.738, test=0.604) total time= 2.3min
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.730, test=0.630) total time= 2.0min
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.736, test=0.599) total time= 2.0min
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.728, test=0.605) total time= 2.3min
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.735, test=0.620) total time= 2.1min
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.738, test=0.604) total time= 2.2min
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.730, test=0.630) total time= 2.0min
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.969, test=0.691) total time= 5.0min
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.967, test=0.721) total time= 4.9min
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.968, test=0.691) total time= 4.3min
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.968, test=0.700) total time= 4.8min
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.970, test=0.717) total time= 4.3min
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.969, test=0.691) total time= 4.6min
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.967, test=0.721) total time= 4.7min
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.968, test=0.691) total time= 4.5min
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.968, test=0.700) total time= 4.6min
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.970, test=0.717) total time= 4.4min
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time= 6.9min
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.734) total time= 6.6min
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.715) total time= 6.9min
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.721) total time= 7.0min
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time= 6.9min
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time= 7.2min
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.734) total time= 6.6min
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.715) total time= 7.2min
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.721) total time= 7.0min
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time= 7.1min
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time= 9.1min
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time= 8.9min
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.719) total time= 9.6min
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time= 9.4min
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.723) total time= 9.2min
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time= 9.2min
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.735) total time= 8.6min
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.719) total time= 9.9min
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time= 9.3min
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.723) total time= 9.8min
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time=12.1min
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.733) total time=11.9min
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.719) total time=11.5min
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.708) total time=10.6min
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=11.0min
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.711) total time=12.6min
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.733) total time=11.8min
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.719) total time=11.8min
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.708) total time=10.8min
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=11.3min
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time=12.7min
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=13.2min
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.723) total time=12.8min
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=12.1min
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=12.6min
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.714) total time=19.0min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=19.0min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.721) total time=17.1min
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.713) total time=11.7min
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.721) total time=15.9min
# tuned hpyerparameters :(best parameters)  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.7201946986285808
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.268, test=0.263) total time=   6.6s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.267, test=0.264) total time=   7.4s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.270, test=0.259) total time=   7.3s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.265, test=0.263) total time=   7.3s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.292, test=0.284) total time=   7.7s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.257) total time=  21.2s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.264) total time=  21.8s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.259) total time=  19.0s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.265, test=0.261) total time=  27.7s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.260, test=0.267) total time=  18.6s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.263, test=0.257) total time=  33.6s
# [CV 2/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.261, test=0.264) total time=  33.8s
# [CV 3/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.259) total time=  33.6s
# [CV 4/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.263, test=0.261) total time=  33.9s
# [CV 5/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.260, test=0.267) total time=  33.0s
# [CV 1/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.845, test=0.435) total time=  14.5s
# [CV 2/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.856, test=0.454) total time=  14.4s
# [CV 3/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.871, test=0.406) total time=  14.2s
# [CV 4/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.858, test=0.392) total time=  14.4s
# [CV 5/5] END max_depth=50, n_estimators=10, random_state=42;, score=(train=0.856, test=0.467) total time=  14.2s
# [CV 1/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.909, test=0.384) total time=  55.3s
# [CV 2/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.912, test=0.398) total time=  55.2s
# [CV 3/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.923, test=0.356) total time=  54.6s
# [CV 4/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.903, test=0.382) total time=  55.9s
# [CV 5/5] END max_depth=50, n_estimators=50, random_state=42;, score=(train=0.906, test=0.404) total time=  55.6s
# [CV 1/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.933, test=0.371) total time= 1.8min
# [CV 2/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.932, test=0.385) total time= 1.8min
# [CV 3/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.939, test=0.382) total time= 1.8min
# [CV 4/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.922, test=0.370) total time= 1.8min
# [CV 5/5] END max_depth=50, n_estimators=100, random_state=42;, score=(train=0.931, test=0.368) total time= 1.8min
# [CV 1/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.979, test=0.468) total time=  17.2s
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.971, test=0.481) total time=  17.2s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.976, test=0.459) total time=  16.9s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.977, test=0.441) total time=  17.1s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.979, test=0.471) total time=  16.5s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.437) total time= 1.2min
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.430) total time= 1.1min
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.431) total time= 1.1min
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.407) total time= 1.2min
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.423) total time= 1.1min
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.408) total time= 2.2min
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.427) total time= 2.2min
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.430) total time= 2.2min
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.400) total time= 2.3min
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.418) total time= 2.2min
# tuned hpyerparameters :(best parameters)  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# accuracy : 0.46384521985630744
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.655, test=0.534) total time=   7.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.645, test=0.556) total time=   7.4s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.658, test=0.557) total time=   7.2s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.648, test=0.537) total time=   7.3s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.650, test=0.578) total time=   7.1s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.655, test=0.534) total time=   7.0s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.645, test=0.556) total time=   7.4s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.658, test=0.557) total time=   7.0s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.648, test=0.537) total time=   7.3s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.650, test=0.578) total time=   7.4s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.946, test=0.709) total time=   8.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.939, test=0.717) total time=   9.6s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.945, test=0.708) total time=   8.9s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.945, test=0.707) total time=   9.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.945, test=0.721) total time=   9.6s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.946, test=0.709) total time=   8.9s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.939, test=0.717) total time=   9.7s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.945, test=0.708) total time=   9.0s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.945, test=0.707) total time=   9.5s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.945, test=0.721) total time=   9.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.739) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=   9.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.738) total time=   9.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=  11.8s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.741) total time=  12.8s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=  12.0s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.730) total time=  13.1s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.736) total time=  12.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=   9.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.730) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=   8.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.727) total time=   8.9s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=  15.1s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  17.7s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.730) total time=  16.4s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.724) total time=  16.9s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  16.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.717) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.728) total time=   8.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.719) total time=   8.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=   9.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=  25.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=  27.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.728) total time=  27.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.718) total time=  25.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=  28.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.719) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.729) total time=   9.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=   9.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.721) total time=  28.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.725) total time=  29.7s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=  28.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.717) total time=  26.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.721) total time=  29.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.722) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.724) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.727) total time=   9.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.717) total time=   9.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.718) total time=   9.2s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  30.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.726) total time=  29.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.726) total time=  24.9s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.714) total time=  27.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.720) total time=  30.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# tuned hpyerparameters :(best parameters)  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.7313094362334888
# Model 3: NB Multinomial
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..............., score=(train=0.680, test=0.497) total time=  32.2s
# [CV 2/5] END ..............., score=(train=0.675, test=0.516) total time=  32.4s
# [CV 3/5] END ..............., score=(train=0.679, test=0.500) total time=  32.3s
# [CV 4/5] END ..............., score=(train=0.672, test=0.502) total time=  32.3s
# [CV 5/5] END ..............., score=(train=0.682, test=0.508) total time=  32.3s
# tuned hpyerparameters :(best parameters)  {}
# accuracy : 0.5045548673976843
# Model 4: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.678, test=0.451) total time=  13.6s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.678, test=0.445) total time=  14.2s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.664, test=0.424) total time=  14.7s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.676, test=0.423) total time=  15.1s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.669, test=0.440) total time=  15.2s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.437) total time=  15.1s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.458) total time=  15.1s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.435) total time=  15.4s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.422) total time=  15.1s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.448) total time=  15.1s
# tuned hpyerparameters :(best parameters)  {'n_neighbors': 3, 'weights': 'distance'}
# accuracy : 0.4401026449421014
# TF-IDF
# Lemma: (7000, 79502)
# POS: (7000, 218)
# TAG: (7000, 200)
# Other features: (7000, 7304)
# Final vector shape: (7000, 87224)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.0s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=  11.3s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.4s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.3s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=  11.3s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.5s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=  11.4s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.3s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=  11.3s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=  11.5s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.263, test=0.257) total time=  17.5s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.269, test=0.264) total time=  17.4s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.264, test=0.259) total time=  18.8s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.264, test=0.263) total time=  19.3s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.258, test=0.261) total time=  19.6s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.263, test=0.257) total time=  17.5s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.269, test=0.264) total time=  17.5s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.264, test=0.259) total time=  18.9s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.264, test=0.263) total time=  19.1s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.258, test=0.261) total time=  19.6s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.527, test=0.423) total time=  39.7s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.526, test=0.445) total time=  45.3s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.528, test=0.446) total time=  43.3s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.529, test=0.435) total time=  42.6s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.527, test=0.451) total time=  44.0s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.527, test=0.423) total time=  40.0s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.526, test=0.445) total time=  45.0s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.528, test=0.446) total time=  42.9s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.529, test=0.435) total time=  42.3s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.527, test=0.451) total time=  44.4s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.927, test=0.603) total time= 1.5min
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.924, test=0.618) total time= 1.7min
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.926, test=0.628) total time= 1.9min
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.928, test=0.596) total time= 1.6min
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.930, test=0.631) total time= 1.7min
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.927, test=0.603) total time= 1.5min
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.924, test=0.618) total time= 1.7min
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.926, test=0.628) total time= 1.7min
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.928, test=0.596) total time= 1.6min
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.930, test=0.631) total time= 1.7min
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.640) total time= 2.7min
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.664) total time= 3.1min
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.664) total time= 2.9min
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.645) total time= 2.8min
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time= 2.7min
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.640) total time= 2.7min
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.664) total time= 3.1min
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.664) total time= 2.9min
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.645) total time= 2.8min
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time= 2.8min
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.651) total time= 4.1min
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.681) total time= 4.2min
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.675) total time= 4.0min
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.659) total time= 4.0min
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.671) total time= 4.0min
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.651) total time= 4.1min
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.681) total time= 4.3min
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.675) total time= 3.9min
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.659) total time= 3.9min
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.671) total time= 4.0min
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.655) total time= 5.5min
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time= 5.6min
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.679) total time= 5.4min
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time= 5.0min
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.680) total time= 5.4min
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.655) total time= 5.5min
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time= 5.6min
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.679) total time= 5.4min
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.674) total time= 5.1min
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.680) total time= 5.5min
# tuned hpyerparameters :(best parameters)  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.674617861274069
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.280, test=0.263) total time=   6.6s
# [CV 2/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.276, test=0.266) total time=   6.6s
# [CV 3/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.275, test=0.262) total time=   6.6s
# [CV 4/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.275, test=0.262) total time=   6.7s
# [CV 5/5] END max_depth=10, n_estimators=10, random_state=42;, score=(train=0.286, test=0.282) total time=   6.6s
# [CV 1/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.257) total time=  18.2s
# [CV 2/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.266) total time=  18.2s
# [CV 3/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.262, test=0.259) total time=  18.3s
# [CV 4/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.267, test=0.261) total time=  18.2s
# [CV 5/5] END max_depth=10, n_estimators=50, random_state=42;, score=(train=0.263, test=0.267) total time=  18.2s
# [CV 1/5] END max_depth=10, n_estimators=100, random_state=42;, score=(train=0.262, test=0.257) total time=  32.9s
# ...
# [CV 2/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.983, test=0.450) total time=  15.7s
# [CV 3/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.984, test=0.467) total time=  16.6s
# [CV 4/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.980, test=0.463) total time=  16.2s
# [CV 5/5] END max_depth=100, n_estimators=10, random_state=42;, score=(train=0.978, test=0.504) total time=  16.2s
# [CV 1/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.403) total time= 1.1min
# [CV 2/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.998, test=0.414) total time= 1.1min
# [CV 3/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.406) total time= 1.1min
# [CV 4/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.419) total time= 1.1min
# [CV 5/5] END max_depth=100, n_estimators=50, random_state=42;, score=(train=0.999, test=0.434) total time= 1.1min
# [CV 1/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.411) total time= 2.1min
# [CV 2/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.411) total time= 2.1min
# [CV 3/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.411) total time= 2.1min
# [CV 4/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=1.000, test=0.398) total time= 2.1min
# [CV 5/5] END max_depth=100, n_estimators=100, random_state=42;, score=(train=0.999, test=0.410) total time= 2.2min
# tuned hpyerparameters :(best parameters)  {'max_depth': 100, 'n_estimators': 10, 'random_state': 42}
# accuracy : 0.4608779132685129
# Model 2: SVM Lineal
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.2s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   4.2s
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.2s
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.2s
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   4.3s
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.3s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.257) total time=   4.2s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.3s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.256, test=0.255) total time=   4.2s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.255, test=0.258) total time=   4.2s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.417, test=0.370) total time=   4.2s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.420, test=0.364) total time=   4.2s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.421, test=0.360) total time=   4.2s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.420, test=0.362) total time=   4.2s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.419, test=0.375) total time=   4.2s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.417, test=0.370) total time=   4.2s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.420, test=0.364) total time=   4.2s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.421, test=0.360) total time=   4.3s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.420, test=0.362) total time=   4.2s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.419, test=0.375) total time=   4.2s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.865, test=0.588) total time=   4.3s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.862, test=0.598) total time=   4.2s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.865, test=0.599) total time=   4.3s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.863, test=0.578) total time=   4.2s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.871, test=0.621) total time=   4.3s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.865, test=0.588) total time=   4.3s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.862, test=0.598) total time=   4.3s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.865, test=0.599) total time=   4.3s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.863, test=0.578) total time=   4.3s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.871, test=0.621) total time=   4.3s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.661) total time=   4.5s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.697) total time=   4.6s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.674) total time=   4.6s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.680) total time=   4.6s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   4.6s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.661) total time=   4.6s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.697) total time=   4.6s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.674) total time=   4.6s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.680) total time=   4.5s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.685) total time=   4.5s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=   7.1s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   7.2s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.685) total time=   6.7s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.692) total time=   6.7s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   7.1s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=   7.1s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   7.3s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.685) total time=   6.7s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.692) total time=   6.6s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.696) total time=   7.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=   7.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.692) total time=   8.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.684) total time=   7.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.687) total time=   7.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.690) total time=   7.7s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.664) total time=  33.3s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=  33.1s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.684) total time=  26.6s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.687) total time=  25.8s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.690) total time=  32.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.662) total time=   8.1s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.689) total time=   8.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.685) total time=   7.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=1.000, test=0.690) total time=   7.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=0.999, test=0.692) total time=   7.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.663) total time=  39.4s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.690) total time=  39.0s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.682) total time=  36.5s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=1.000, test=0.687) total time=  33.6s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=0.999, test=0.691) total time=  37.7s
# tuned hpyerparameters :(best parameters)  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : 0.6863103279949436
# Model 3: NB Multinomial
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END ..............., score=(train=0.285, test=0.267) total time=   3.1s
# [CV 2/5] END ..............., score=(train=0.281, test=0.274) total time=   3.2s
# [CV 3/5] END ..............., score=(train=0.286, test=0.268) total time=   3.2s
# [CV 4/5] END ..............., score=(train=0.283, test=0.265) total time=   3.2s
# [CV 5/5] END ..............., score=(train=0.283, test=0.273) total time=   3.1s
# tuned hpyerparameters :(best parameters)  {}
# accuracy : 0.2691606767822071
# Model 4: KNN
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END n_neighbors=3, weights=uniform;, score=(train=0.690, test=0.420) total time=  11.9s
# [CV 2/5] END n_neighbors=3, weights=uniform;, score=(train=0.678, test=0.443) total time=  13.0s
# [CV 3/5] END n_neighbors=3, weights=uniform;, score=(train=0.687, test=0.421) total time=  13.0s
# [CV 4/5] END n_neighbors=3, weights=uniform;, score=(train=0.680, test=0.437) total time=  13.1s
# [CV 5/5] END n_neighbors=3, weights=uniform;, score=(train=0.681, test=0.437) total time=  13.1s
# [CV 1/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.430) total time=  13.1s
# [CV 2/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.451) total time=  13.3s
# [CV 3/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.424) total time=  13.3s
# [CV 4/5] END n_neighbors=3, weights=distance;, score=(train=1.000, test=0.414) total time=  13.3s
# [CV 5/5] END n_neighbors=3, weights=distance;, score=(train=0.999, test=0.447) total time=  13.0s
# tuned hpyerparameters :(best parameters)  {'n_neighbors': 3, 'weights': 'distance'}
# accuracy : 0.4331108226887278

# %%
for i in range(2):
  if i == 0:
    print('Count vectorizer')
    vectorizer = CountVectorizer(ngram_range = (1,3), lowercase = False)
    oth_feats_vectorizer = CountVectorizer(ngram_range = (1,3), lowercase = False)
  else:
    print('TF-IDF')
    vectorizer = TfidfVectorizer(ngram_range = (1,3), lowercase = False)
    oth_feats_vectorizer = TfidfVectorizer(ngram_range = (1,3), lowercase = False)

  ml_homo = rcm.RobustMachineLearningModel(models=models,
                                       model_names=model_names,
                                       train_data=training_p,
                                       x_label_column=x_label_column,
                                       y_label_column=y_label_column,
                                       folds=folds,
                                       grid_params=grid_params,
                                       path_to_save_models=path_to_save_models,
                                       path_to_save_vectorizer=path_to_save_vectorizers,
                                       lemma=True,
                                       pos=True,
                                       tag=True,
                                       other_features=True,
                                       vectorizer=vectorizer,
                                       oth_feats_vectorizer=oth_feats_vectorizer,
                                       language='es')
  ml_homo.get_best_cross_validation()
# Out:
# Count vectorizer
# Lemma: (7000, 184433)
# POS: (7000, 1986)
# TAG: (7000, 1917)
# Other features: (7000, 20581)
# Final vector shape: (7000, 208917)
# Model 0: Regresión logística
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   7.1s
# [CV 2/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   6.8s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_base.py", line 419, in predict
#     scores = self.decision_function(X)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_base.py", line 401, in decision_function
#     scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\extmath.py", line 189, in safe_sparse_dot
#     ret = a @ b
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 2.18 GiB for an array with shape (1400, 208917) and data type float64
#
#   warnings.warn(
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 234, in __call__
#     return self._score(
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 276, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_scorer.py", line 73, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_base.py", line 419, in predict
#     scores = self.decision_function(X)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_base.py", line 401, in decision_function
#     scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\extmath.py", line 189, in safe_sparse_dot
#     ret = a @ b
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 8.72 GiB for an array with shape (5600, 208917) and data type float64
#
#   warnings.warn(
# [CV 3/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time= 3.3min
# [CV 4/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time= 1.1min
# [CV 5/5] END C=0.001, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time= 1.2min
# [CV 1/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   5.9s
# [CV 2/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 3/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.9s
# [CV 4/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.5s
# [CV 5/5] END C=0.001, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 3/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 5/5] END C=0.01, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 2/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 4/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 5/5] END C=0.01, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 2/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 4/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=0.1, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 2/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 3/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 5/5] END C=0.1, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 5/5] END C=1.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 2/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 3/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=1.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 5/5] END C=10.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 1/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 4/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=10.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 4/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=100.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 2/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 3/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 4/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=100.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 2/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# [CV 3/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.1s
# [CV 5/5] END C=1000.0, max_iter=1000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 1/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.4s
# [CV 2/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 3/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 4/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.2s
# [CV 5/5] END C=1000.0, max_iter=10000, penalty=l2, random_state=42;, score=(train=nan, test=nan) total time=   4.3s
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 69 fits failed out of a total of 70.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 69 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_logistic.py", line 1196, in fit
#     X, y = self._validate_data(
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\base.py", line 565, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py", line 1106, in check_X_y
#     X = check_array(
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
# numpy.core._exceptions._ArrayMemoryError: Unable to allocate 8.72 GiB for an array with shape (5600, 208917) and data type float64
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\qk_le\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the train scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# tuned hpyerparameters :(best parameters)  {'C': 0.001, 'max_iter': 1000, 'penalty': 'l2', 'random_state': 42}
# accuracy : nan
# Model 1: Random Forest
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\qk_le\OneDrive\Documentos\Provisional Python\001-Best-Hyperparams-Task1.ipynb Cell 19 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a>   oth_feats_vectorizer = TfidfVectorizer(ngram_range = (1,3), lowercase = False)
#      <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> ml_homo = rcm.RobustMachineLearningModel(models=models,
#      <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a>                                      model_names=model_names,
#      <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a>                                      train_data=training_p,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a>                                      oth_feats_vectorizer=oth_feats_vectorizer,
#      <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=25'>26</a>                                      language='es')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/qk_le/OneDrive/Documentos/Provisional%20Python/001-Best-Hyperparams-Task1.ipynb#X24sZmlsZQ%3D%3D?line=26'>27</a> ml_homo.get_best_cross_validation()
#
# File c:\Users\qk_le\OneDrive\Documentos\Provisional Python\Scripts\robust_classic_model.py:86, in RobustMachineLearningModel.get_best_cross_validation(self)
#      79 param_grid = self.grid_params
#      80 grid_search = GridSearchCV(model,
#      81                            param_grid[j],
#      82                            cv=kFold_cv.split(X_train, y_train),
#      83                            scoring = 'f1_macro',
#      84                            verbose=3,
#      85                            return_train_score = True)
# ---> 86 grid_search.fit(X_train, y_train)
#      88 print("tuned hpyerparameters :(best parameters) ",grid_search.best_params_)
#      89 print("accuracy :",grid_search.best_score_)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1043, in Parallel.__call__(self, iterable)
#    1034 try:
#    1035     # Only set self._iterating to True if at least a batch
#    1036     # was dispatched. In particular this covers the edge
#    (...)
#    1040     # was very quick and its callback already dispatched all the
#    1041     # remaining jobs.
#    1042     self._iterating = False
# -> 1043     if self.dispatch_one_batch(iterator):
#    1044         self._iterating = self._original_iterator is not None
#    1046     while self.dispatch_one_batch(iterator):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_validation.py:678, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     674     estimator = estimator.set_params(**cloned_parameters)
#     676 start_time = time.time()
# --> 678 X_train, y_train = _safe_split(estimator, X, y, train)
#     679 X_test, y_test = _safe_split(estimator, X, y, test, train)
#     681 result = {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\metaestimators.py:233, in _safe_split(estimator, X, y, indices, train_indices)
#     231         X_subset = X[np.ix_(indices, train_indices)]
#     232 else:
# --> 233     X_subset = _safe_indexing(X, indices)
#     235 if y is not None:
#     236     y_subset = _safe_indexing(y, indices)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\__init__.py:356, in _safe_indexing(X, indices, axis)
#     354     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     355 elif hasattr(X, "shape"):
# --> 356     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     357 else:
#     358     return _list_indexing(X, indices, indices_dtype)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\utils\__init__.py:185, in _array_indexing(array, key, key_dtype, axis)
#     183 if isinstance(key, tuple):
#     184     key = list(key)
# --> 185 return array[key] if axis == 0 else array[:, key]
#
# MemoryError: Unable to allocate 8.72 GiB for an array with shape (5600, 208917) and data type int64
